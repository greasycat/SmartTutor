# %%
import os


id_file = "cache/arxiv/arxiv_ids.txt"

# read 1line
ids = set()
with open(id_file, "r") as f:
    for line in f:
        # split by v and take the first part
        ids.add(line.split("v")[0].strip())

ids = sorted(list(ids))
ids[:5]
# Out:
# ['0803.0476', '0912.3995', '1103.0398', '1112.6209', '1206.5538']

# %%
from langchain_community.retrievers import ArxivRetriever

retriever = ArxivRetriever(
    load_max_docs=2,
    get_ful_documents=True,
)

# %%
book1 = retriever.invoke("0912.3995v4")

# %%
from langchain_community.document_loaders import ArxivLoader

# Supports all arguments of `ArxivAPIWrapper`
loader = ArxivLoader(
    query="reasoning",
    load_max_docs=2,
)
# Out:
# 'Many applications require optimizing an unknown, noisy function that is\nexpensive to evaluate. We formalize this task as a multi-armed bandit problem,\nwhere the payoff function is either sampled from a Gaussian process (GP) or has\nlow RKHS norm. We resolve the important open problem of deriving regret bounds\nfor this setting, which imply novel convergence rates for GP optimization. We\nanalyze GP-UCB, an intuitive upper-confidence based algorithm, and bound its\ncumulative regret in terms of maximal information gain, establishing a novel\nconnection between GP optimization and experimental design. Moreover, by\nbounding the latter in terms of operator spectra, we obtain explicit sublinear\nregret bounds for many commonly used covariance functions. In some important\ncases, our bounds have surprisingly weak dependence on the dimensionality. In\nour experiments on real sensor data, GP-UCB compares favorably with other\nheuristical GP optimization approaches.'

# %%
folder_to_save = "cache/arxiv/papers"
# create folder if not exists
os.makedirs(folder_to_save, exist_ok=True)

# obtain content
from langchain_community.document_loaders import ArxivLoader
from langchain_core.load import dumpd, dumps, load, loads
from json import dump
import time
for id in ids:
    # skip if file already exists
    filename = f"{id}.json"  # Change file extension to .pkl for pickle files
    if os.path.exists(os.path.join(folder_to_save, filename)):
        print(f"Skipping {id} because it already exists")
        continue

    try:
        loader = ArxivLoader(
            query=id,
            load_max_docs=1,
        )

        print()
        print("loading", id)
        paper = loader.load()
    except ConnectionError as e:
        print("ConnectionError, skipping")
        time.sleep(5)
        continue
    print("loaded", id)
    print()

    if isinstance(paper, list):
        if len(paper) > 0:
            paper = paper[0]
        else:
            print("no paper for id", id)
            continue

    with open(os.path.join(folder_to_save, filename), "w") as f:  # Use "wb" for writing bytes
        dump(dumps(paper), f)
        print(f"Saved {id}")
    
    # sleep 3 seconds
    time.sleep(8)
# Out:
# Skipping 0803.0476 because it already exists
# Skipping 0912.3995 because it already exists
# Skipping 1103.0398 because it already exists
# Skipping 1112.6209 because it already exists
# Skipping 1206.5538 because it already exists
# Skipping 1207.0580 because it already exists
# Skipping 1301.3781 because it already exists
# Skipping 1302.4389 because it already exists
# Skipping 1303.5778 because it already exists
# Skipping 1308.0850 because it already exists
# Skipping 1310.1531 because it already exists
# Skipping 1311.2901 because it already exists
# Skipping 1312.4400 because it already exists
# Skipping 1312.5602 because it already exists
# Skipping 1312.6114 because it already exists
# Skipping 1312.6199 because it already exists
# Skipping 1312.6229 because it already exists
# Skipping 1404.2188 because it already exists
# Skipping 1404.7828 because it already exists
# Skipping 1405.3531 because it already exists
# Skipping 1405.4053 because it already exists
# Skipping 1406.1078 because it already exists
# Skipping 1406.2572 because it already exists
# Skipping 1406.4729 because it already exists
# Skipping 1406.6247 because it already exists
# Skipping 1408.5093 because it already exists
# Skipping 1408.5882 because it already exists
# Skipping 1409.0473 because it already exists
# Skipping 1409.0575 because it already exists
# Skipping 1409.1259 because it already exists
# Skipping 1409.1556 because it already exists
# Skipping 1409.2329 because it already exists
# Skipping 1409.3215 because it already exists
# Skipping 1410.3831 because it already exists
# Skipping 1410.3916 because it already exists
# Skipping 1410.5401 because it already exists
# Skipping 1410.8206 because it already exists
# Skipping 1412.0035 because it already exists
# Skipping 1412.1842 because it already exists
# Skipping 1412.1897 because it already exists
# Skipping 1412.3555 because it already exists
# Skipping 1412.4564 because it already exists
# Skipping 1412.6621 because it already exists
# Skipping 1412.6980 because it already exists
# Skipping 1412.7062 because it already exists
# Skipping 1501.00092 because it already exists
# Skipping 1502.03044 because it already exists
# Skipping 1502.03167 because it already exists
# Skipping 1502.04623 because it already exists
# Skipping 1502.05082 because it already exists
# Skipping 1502.05698 because it already exists
# Skipping 1503.00075 because it already exists
# Skipping 1503.00949 because it already exists
# Skipping 1503.02406 because it already exists
# Skipping 1503.02531 because it already exists
# Skipping 1503.03585 because it already exists
# Skipping 1503.04069 because it already exists
# Skipping 1503.05671 because it already exists
# Skipping 1505.00387 because it already exists
# Skipping 1505.03540 because it already exists
# Skipping 1505.04366 because it already exists
# Skipping 1505.04597 because it already exists
# Skipping 1506.02078 because it already exists
# Skipping 1506.02142 because it already exists
# Skipping 1506.05869 because it already exists
# Skipping 1506.06579 because it already exists
# Skipping 1506.07285 because it already exists
# Skipping 1508.04025 because it already exists
# Skipping 1508.04395 because it already exists
# Skipping 1508.06576 because it already exists
# Skipping 1508.06615 because it already exists
# Skipping 1508.07909 because it already exists
# Skipping 1509.02971 because it already exists
# Skipping 1509.06461 because it already exists
# Skipping 1510.00149 because it already exists
# Skipping 1511.06434 because it already exists
# Skipping 1511.07289 because it already exists
# Skipping 1512.02325 because it already exists
# Skipping 1512.02595 because it already exists
# Skipping 1512.03385 because it already exists
# Skipping 1601.01705 because it already exists
# Skipping 1601.06759 because it already exists
# Skipping 1602.01528 because it already exists
# Skipping 1602.02410 because it already exists
# Skipping 1602.02830 because it already exists
# Skipping 1602.07261 because it already exists
# Skipping 1602.07360 because it already exists
# Skipping 1603.02199 because it already exists
# Skipping 1603.02754 because it already exists
# Skipping 1603.04467 because it already exists
# Skipping 1603.05027 because it already exists
# Skipping 1603.06147 because it already exists
# Skipping 1603.06560 because it already exists
# Skipping 1603.08155 because it already exists
# Skipping 1603.08511 because it already exists
# Skipping 1603.08983 because it already exists
# Skipping 1603.09382 because it already exists
# Skipping 1604.00788 because it already exists
# Skipping 1604.08610 because it already exists
# Skipping 1605.09081 because it already exists
# Skipping 1606.00704 because it already exists
# Skipping 1606.01540 because it already exists
# Skipping 1606.01781 because it already exists
# Skipping 1606.02858 because it already exists
# Skipping 1606.04474 because it already exists
# Skipping 1606.05250 because it already exists
# Skipping 1606.05908 because it already exists
# Skipping 1606.08415 because it already exists
# Skipping 1607.01759 because it already exists
# Skipping 1607.06450 because it already exists
# Skipping 1608.00060 because it already exists
# Skipping 1608.06993 because it already exists
# Skipping 1609.03499 because it already exists
# Skipping 1609.03552 because it already exists
# Skipping 1609.08144 because it already exists
# Skipping 1610.09038 because it already exists
# Skipping 1611.01144 because it already exists
# Skipping 1611.03530 because it already exists
# Skipping 1611.04076 because it already exists
# Skipping 1612.03144 because it already exists
# Skipping 1701.07274 because it already exists
# Skipping 1701.07875 because it already exists
# Skipping 1702.01932 because it already exists
# Skipping 1702.03275 because it already exists
# Skipping 1702.06506 because it already exists
# Skipping 1702.07800 because it already exists
# Skipping 1702.07825 because it already exists
# Skipping 1703.01619 because it already exists
# Skipping 1703.03130 because it already exists
# Skipping 1703.03864 because it already exists
# Skipping 1703.05192 because it already exists
# Skipping 1703.06211 because it already exists
# Skipping 1703.06868 because it already exists
# Skipping 1703.06870 because it already exists
# Skipping 1703.07511 because it already exists
# Skipping 1703.10135 because it already exists
# Skipping 1704.00805 because it already exists
# Skipping 1704.04289 because it already exists
# Skipping 1704.04861 because it already exists
# Skipping 1705.03122 because it already exists
# Skipping 1706.03762 because it already exists
# Skipping 1706.06859 because it already exists
# Skipping 1706.08500 because it already exists
#
# loading 1707.06347
# loaded 1707.06347
#
# Saved 1707.06347
#
# loading 1708.05344
# loaded 1708.05344
#
# Saved 1708.05344
#
# loading 1709.01507
# loaded 1709.01507
#
# Saved 1709.01507
#
# loading 1711.00937
# loaded 1711.00937
#
# Saved 1711.00937
#
# loading 1711.11053
# loaded 1711.11053
#
# Saved 1711.11053
#
# loading 1801.04381
# loaded 1801.04381
#
# Saved 1801.04381
#
# loading 1801.05134
# loaded 1801.05134
#
# Saved 1801.05134
#
# loading 1801.06146
# loaded 1801.06146
#
# Saved 1801.06146
#
# loading 1802.03426
# loaded 1802.03426
#
# Saved 1802.03426
#
# loading 1803.03635
# loaded 1803.03635
#
# Saved 1803.03635
#
# loading 1806.01261
# loaded 1806.01261
#
# Saved 1806.01261
#
# loading 1806.07572
# loaded 1806.07572
#
# Saved 1806.07572
#
# loading 1806.09594
# loaded 1806.09594
#
# Saved 1806.09594
#
# loading 1807.03748
# loaded 1807.03748
#
# Saved 1807.03748
#
# loading 1810.04805
# loaded 1810.04805
#
# Saved 1810.04805
#
# loading 1812.03828
# loaded 1812.03828
#
# Saved 1812.03828
#
# loading 1906.00446
# loaded 1906.00446
#
# Saved 1906.00446
#
# loading 1908.05355
# loaded 1908.05355
#
# Saved 1908.05355
#
# loading 1910.02054
# loaded 1910.02054
#
# Saved 1910.02054
#
# loading 1911.01547
# loaded 1911.01547
#
# Saved 1911.01547
#
# loading 1912.02292
# loaded 1912.02292
#
# Saved 1912.02292
#
# loading 2003.08934
# loaded 2003.08934
#
# Saved 2003.08934
#
# loading 2005.14165
# loaded 2005.14165
#
# Saved 2005.14165
#
# loading 2006.09661
# loaded 2006.09661
#
# Saved 2006.09661
#
# loading 2006.10739
# loaded 2006.10739
#
# Saved 2006.10739
#
# loading 2006.11239
# loaded 2006.11239
#
# Saved 2006.11239
#
# loading 2010.11929
# loaded 2010.11929
#
# Saved 2010.11929
#
# loading 2011.01808
# loaded 2011.01808
#
# Saved 2011.01808
#
# loading 2012.09841
# loaded 2012.09841
#
# Saved 2012.09841
#
# loading 2012.13255
# loaded 2012.13255
#
# Saved 2012.13255
#
# loading 2103.00020
# loaded 2103.00020
#
# Saved 2103.00020
#
# loading 2103.00564
# loaded 2103.00564
#
# Saved 2103.00564
#
# loading 2104.13478
# loaded 2104.13478
#
# Saved 2104.13478
#
# loading 2104.14294
# loaded 2104.14294
#
# Saved 2104.14294
#
# loading 2106.09685
# loaded 2106.09685
#
# Saved 2106.09685
#
# loading 2108.01073
# loaded 2108.01073
#
# Saved 2108.01073
#
# loading 2109.01652
# loaded 2109.01652
#
# Saved 2109.01652
#
# loading 2109.02355
# loaded 2109.02355
#
# Saved 2109.02355
#
# loading 2109.11978
# loaded 2109.11978
#
# Saved 2109.11978
#
# loading 2109.13226
# loaded 2109.13226
#
# Saved 2109.13226
#
# loading 2110.05069
# loaded 2110.05069
#
# Saved 2110.05069
#
# loading 2110.07205
# loaded 2110.07205
#
# Saved 2110.07205
#
# loading 2110.08207
# loaded 2110.08207
#
# Saved 2110.08207
#
# loading 2110.09485
# loaded 2110.09485
#
# Saved 2110.09485
#
# loading 2111.02358
# loaded 2111.02358
#
# Saved 2111.02358
#
# loading 2112.06825
# loaded 2112.06825
#
# Saved 2112.06825
#
# loading 2112.10752
# loaded 2112.10752
#
# Saved 2112.10752
#
# loading 2201.02177
# loaded 2201.02177
#
# Saved 2201.02177
#
# loading 2201.03545
# loaded 2201.03545
#
# Saved 2201.03545
#
# loading 2201.08239
# loaded 2201.08239
#
# Saved 2201.08239
#
# loading 2201.09792
# loaded 2201.09792
#
# Saved 2201.09792
#
# loading 2201.11903
# loaded 2201.11903
#
# Saved 2201.11903
#
# loading 2202.01374
# loaded 2202.01374
#
# Saved 2202.01374
#
# loading 2202.08433
# loaded 2202.08433
#
# Saved 2202.08433
#
# loading 2202.11214
# loaded 2202.11214
#
# Saved 2202.11214
#
# loading 2203.02053
# loaded 2203.02053
#
# Saved 2203.02053
#
# loading 2203.02155
# loaded 2203.02155
#
# Saved 2203.02155
#
# loading 2203.15556
# loaded 2203.15556
#
# Saved 2203.15556
#
# loading 2204.01691
# loaded 2204.01691
#
# Saved 2204.01691
#
# loading 2204.01697
# loaded 2204.01697
#
# Saved 2204.01697
#
# loading 2204.02311
# loaded 2204.02311
#
# Saved 2204.02311
#
# loading 2204.03162
# loaded 2204.03162
#
# Saved 2204.03162
#
# loading 2204.03409
# loaded 2204.03409
#
# Saved 2204.03409
#
# loading 2204.06125
# loaded 2204.06125
#
# Saved 2204.06125
#
# loading 2204.06745
# loaded 2204.06745
#
# Saved 2204.06745
#
# loading 2204.14198
# loaded 2204.14198
#
# Saved 2204.14198
#
# loading 2205.01580
# loaded 2205.01580
#
# Saved 2205.01580
#
# loading 2205.01917
# loaded 2205.01917
#
# Saved 2205.01917
#
# loading 2205.06175
# loaded 2205.06175
#
# Saved 2205.06175
#
# loading 2205.10343
# loaded 2205.10343
#
# Saved 2205.10343
#
# loading 2205.11487
# loaded 2205.11487
#
# Saved 2205.11487
#
# loading 2205.14100
# loaded 2205.14100
#
# Saved 2205.14100
#
# loading 2206.00364
# loaded 2206.00364
#
# Saved 2206.00364
#
# loading 2206.04615
# loaded 2206.04615
#
# Saved 2206.04615
#
# loading 2206.13170
# loaded 2206.13170
#
# Saved 2206.13170
#
# loading 2206.14858
# loaded 2206.14858
#
# Saved 2206.14858
#
# loading 2207.12598
# loaded 2207.12598
#
# Saved 2207.12598
#
# loading 2208.09392
# loaded 2208.09392
#
# Saved 2208.09392
#
# loading 2208.10442
# loaded 2208.10442
#
# Saved 2208.10442
#
# loading 2208.12242
# loaded 2208.12242
#
# Saved 2208.12242
#
# loading 2208.12415
# loaded 2208.12415
#
# Saved 2208.12415
#
# loading 2209.03143
# loaded 2209.03143
#
# Saved 2209.03143
#
# loading 2209.06794
# loaded 2209.06794
#
# Saved 2209.06794
#
# loading 2209.14792
# loaded 2209.14792
#
# Saved 2209.14792
#
# loading 2209.14988
# loaded 2209.14988
#
# Saved 2209.14988
#
# loading 2209.15352
# loaded 2209.15352
#
# Saved 2209.15352
#
# loading 2210.02186
# loaded 2210.02186
#
# Saved 2210.02186
#
# loading 2210.03142
# loaded 2210.03142
#
# Saved 2210.03142
#
# loading 2210.03629
# loaded 2210.03629
#
# Saved 2210.03629
#
# loading 2210.08402
# loaded 2210.08402
#
# Saved 2210.08402
#
# loading 2210.09276
# MuPDF error: syntax error: could not parse color space (1097 0 R)
#
# loaded 2210.09276
#
# Saved 2210.09276
#
# loading 2210.13438
# loaded 2210.13438
#
# Saved 2210.13438
#
# loading 2211.05100
# loaded 2211.05100
#
# Saved 2211.05100
#
# loading 2211.09788
# loaded 2211.09788
#
# Saved 2211.09788
#
# loading 2211.09800
# loaded 2211.09800
#
# Saved 2211.09800
#
# loading 2211.10440
# loaded 2211.10440
#
# Saved 2211.10440
#
# loading 2212.04356
# loaded 2212.04356
#
# Saved 2212.04356
#
# loading 2212.04488
# loaded 2212.04488
#
# Saved 2212.04488
#
# loading 2212.06817
# loaded 2212.06817
#
# Saved 2212.06817
#
# loading 2212.09748
# loaded 2212.09748
#
# Saved 2212.09748
#
# loading 2212.13138
# loaded 2212.13138
#
# Saved 2212.13138
#
# loading 2301.00704
# loaded 2301.00704
#
# Saved 2301.00704
#
# loading 2301.02111
# loaded 2301.02111
#
# Saved 2301.02111
#
# loading 2301.04104
# loaded 2301.04104
#
# Saved 2301.04104
#
# loading 2301.11305
# loaded 2301.11305
#
# Saved 2301.11305
#
# loading 2301.11325
# loaded 2301.11325
#
# Saved 2301.11325
#
# loading 2301.12503
# loaded 2301.12503
#
# Saved 2301.12503
#
# loading 2302.01318
# loaded 2302.01318
#
# Saved 2302.01318
#
# loading 2302.02662
# loaded 2302.02662
#
# Saved 2302.02662
#
# loading 2302.02948
# loaded 2302.02948
#
# Saved 2302.02948
#
# loading 2302.03011
# loaded 2302.03011
#
# Saved 2302.03011
#
# loading 2302.04761
# loaded 2302.04761
#
# Saved 2302.04761
#
# loading 2302.05442
# loaded 2302.05442
#
# Saved 2302.05442
#
# loading 2302.05543
# loaded 2302.05543
#
# Saved 2302.05543
#
# loading 2302.06675
# loaded 2302.06675
#
# Saved 2302.06675
#
# loading 2302.13971
# loaded 2302.13971
#
# Saved 2302.13971
#
# loading 2302.14045
# loaded 2302.14045
#
# Saved 2302.14045
#
# loading 2303.00001
# loaded 2303.00001
#
# Saved 2303.00001
#
# loading 2303.01037
# loaded 2303.01037
#
# Saved 2303.01037
#
# loading 2303.03378
# loaded 2303.03378
#
# Saved 2303.03378
#
# loading 2303.04671
# loaded 2303.04671
#
# Saved 2303.04671
#
# loading 2303.05511
# loaded 2303.05511
#
# Saved 2303.05511
#
# loading 2303.06296
# loaded 2303.06296
#
# Saved 2303.06296
#
# loading 2303.12712
# loaded 2303.12712
#
# Saved 2303.12712
#
# loading 2303.17564
# loaded 2303.17564
#
# Saved 2303.17564
#
# loading 2303.17580
# loaded 2303.17580
#
# Saved 2303.17580
#
# loading 2304.02643
# loaded 2304.02643
#
# Saved 2304.02643
#
# loading 2304.03277
# loaded 2304.03277
#
# Saved 2304.03277
#
# loading 2304.03442
# loaded 2304.03442
#
# Saved 2304.03442
#
# loading 2304.07193
# loaded 2304.07193
#
# Saved 2304.07193
#
# loading 2304.08466
# loaded 2304.08466
#
# Saved 2304.08466
#
# loading 2304.08485
# loaded 2304.08485
#
# Saved 2304.08485
#
# loading 2304.08818
# loaded 2304.08818
#
# Saved 2304.08818
#
# loading 2304.12306
# loaded 2304.12306
#
# Saved 2304.12306
#
# loading 2304.12995
# loaded 2304.12995
#
# Saved 2304.12995
#
# loading 2305.10403
# loaded 2305.10403
#
# Saved 2305.10403
#
# loading 2305.10601
# loaded 2305.10601
#
# Saved 2305.10601
#
# loading 2305.10973
# loaded 2305.10973
#
# Saved 2305.10973
#
# loading 2305.11206
# loaded 2305.11206
#
# Saved 2305.11206
#
# loading 2305.13516
# loaded 2305.13516
#
# Saved 2305.13516
#
# loading 2305.14314
# loaded 2305.14314
#
# Saved 2305.14314
#
# loading 2305.16291
# loaded 2305.16291
#
# Saved 2305.16291
#
# loading 2305.16367
# loaded 2305.16367
#
# Saved 2305.16367
#
# loading 2305.18290
# loaded 2305.18290
#
# Saved 2305.18290
#
# loading 2305.19466
# loaded 2305.19466
#
# Saved 2305.19466
#
# loading 2306.03092
# loaded 2306.03092
#
# Saved 2306.03092
#
# loading 2306.05284
# loaded 2306.05284
#
# Saved 2306.05284
#
# loading 2306.12925
# loaded 2306.12925
#
# Saved 2306.12925
#
# loading 2306.15687
# loaded 2306.15687
#
# Saved 2306.15687
#
# loading 2307.01952
# loaded 2307.01952
#
# Saved 2307.01952
#
# loading 2307.10802
# loaded 2307.10802
#
# Saved 2307.10802
#
# loading 2307.15818
# loaded 2307.15818
#
# Saved 2307.15818
#
# loading 2307.16789
# loaded 2307.16789
#
# Saved 2307.16789
#
# loading 2308.00352
# loaded 2308.00352
#
# Saved 2308.00352
#
# loading 2308.02151
# loaded 2308.02151
#
# Saved 2308.02151
#
# loading 2308.11596
# loaded 2308.11596
#
# Saved 2308.11596
#
# loading 2308.12950
# loaded 2308.12950
#
# Saved 2308.12950
#
# loading 2308.12966
# loaded 2308.12966
#
# Saved 2308.12966
#
# loading 2308.16512
# loaded 2308.16512
#
# Saved 2308.16512
#
# loading 2309.00267
# loaded 2309.00267
#
# Saved 2309.00267
#
# loading 2309.03409
# loaded 2309.03409
#
# Saved 2309.03409
#
# loading 2309.16588
# loaded 2309.16588
#
# Saved 2309.16588
#
# loading 2309.17453
# loaded 2309.17453
#
# Saved 2309.17453
#
# loading 2310.12931
# loaded 2310.12931
#
# Saved 2310.12931
#
# loading 2311.06242
# loaded 2311.06242
#
# Saved 2311.06242
#
# loading 2312.14125
# loaded 2312.14125
#
# Saved 2312.14125

# %%
# Out:
# {'Published': '2008-07-25',
#  'Title': 'Fast unfolding of communities in large networks',
#  'Authors': 'Vincent D. Blondel, Jean-Loup Guillaume, Renaud Lambiotte, Etienne Lefebvre',
#  'Summary': 'We propose a simple method to extract the community structure of large\nnetworks. Our method is a heuristic method that is based on modularity\noptimization. It is shown to outperform all other known community detection\nmethod in terms of computation time. Moreover, the quality of the communities\ndetected is very good, as measured by the so-called modularity. This is shown\nfirst by identifying language communities in a Belgian mobile phone network of\n2.6 million customers and by analyzing a web graph of 118 million nodes and\nmore than one billion links. The accuracy of our algorithm is also verified on\nad-hoc modular networks. .'}
